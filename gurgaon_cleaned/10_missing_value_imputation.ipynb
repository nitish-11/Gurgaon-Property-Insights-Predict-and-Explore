# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../gurgaon_data/gurgaon_properties_outlier_treated.csv')

# %%
df.shape
# Out:
# (3561, 24)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1014
# agePossession             0
# super_built_up_area    1686
# built_up_area          1976
# carpet_area            1719
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %% [markdown]
# ### Built up area

# %%
#import column for us, user will input the value of build up area required
# hence there should be not missing values, need to fill the missing values through logical steps
# important parameter

# %%
sns.scatterplot(x=df['built_up_area'],y=df['super_built_up_area'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='super_built_up_area'>

# %%
sns.scatterplot(x=df['built_up_area'],y=df['carpet_area'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='carpet_area'>

# %%
df[((df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & (df['carpet_area'].isnull()))].shape
# Out:
# (7, 24)

# %%
#all three present
all_present_df = df[~((df['super_built_up_area'].isnull()) | (df['built_up_area'].isnull()) | (df['carpet_area'].isnull()))]

# %%
all_present_df.shape
# Out:
# (531, 24)

# %%
super_to_built_up_ratio = (all_present_df['super_built_up_area']/all_present_df['built_up_area']).median()

# %%
carpet_to_built_up_ratio = (all_present_df['carpet_area']/all_present_df['built_up_area']).median()

# %%
print(super_to_built_up_ratio,'and',carpet_to_built_up_ratio)
# Out:
# 1.105263157894737 and 0.9

# %%
# built up and carpet present
# built up area not there
sbc_df = df[~(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & ~(df['carpet_area'].isnull())]

# %%
sbc_df.head()
# Out:
#    property_type                  society      sector  price  price_per_sqft  \
# 0           flat  signature global park 4   sector 36   0.82          7586.0
# 4           flat           suncity avenue  sector 102   0.48          9023.0
# 38          flat             corona optus  sector 37c   1.25          7176.0
# 40          flat               m3m merlin   sector 67   2.80         13679.0
# 45          flat      smart world orchard   sector 61   2.10         13752.0
#
#       area                                       areaWithType  bedRoom  \
# 0   1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...        3
# 4    532.0  Super Built up area 632(58.71 sq.m.)Carpet are...        2
# 38  1742.0  Super Built up area 1735(161.19 sq.m.)Carpet a...        3
# 40  2047.0  Super Built up area 2047(190.17 sq.m.)Carpet a...        3
# 45  1527.0  Super Built up area 1549(143.91 sq.m.)Carpet a...        3
#
#     bathroom balcony  floorNum      facing       agePossession  \
# ...

# %%
sbc_df.loc[:, 'built_up_area'] = sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/0.9))/2))

# %%
df.update(sbc_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1014
# agePossession             0
# super_built_up_area    1686
# built_up_area          1555
# carpet_area            1719
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
# only super_built_up_area and carpet area is null
sb_df = df[~(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & (df['carpet_area'].isnull())]

# %%
sb_df.head()
# Out:
#    property_type                      society       sector  price  \
# 5           flat               paras quartier  gwal pahari   7.50
# 6           flat       experion the heartsong   sector 108   2.00
# 7           flat      adani m2k oyster grande   sector 102   1.90
# 12          flat               ats tourmaline   sector 109   2.25
# 15          flat  bestech park view sanskruti    sector 92   1.55
#
#     price_per_sqft    area                            areaWithType  bedRoom  \
# 5          14019.0  5350.0  Super Built up area 5350(497.03 sq.m.)        4
# 6           8554.0  2338.0  Super Built up area 2338(217.21 sq.m.)        3
# 7           9104.0  2087.0  Super Built up area 1889(175.49 sq.m.)        3
# 12          8704.0  2585.0  Super Built up area 2585(240.15 sq.m.)        3
# 15          7568.0  2048.0  Super Built up area 1995(185.34 sq.m.)        3
#
#     bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105),inplace=True)
# Out:
# C:\Users\nitis\AppData\Local\Temp\ipykernel_10800\1714170073.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105),inplace=True)
# C:\Users\nitis\AppData\Local\Temp\ipykernel_10800\1714170073.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.update(sb_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1014
# agePossession             0
# super_built_up_area    1686
# built_up_area           680
# carpet_area            1719
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
# only carpet area is present here
c_df = df[(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & ~(df['carpet_area'].isnull())]

# %%
c_df.head()
# Out:
#    property_type                           society     sector  price  \
# 1           flat                  smart world gems  sector 89   0.95
# 11          flat                  dlf regency park  sector 28   1.60
# 13          flat  emaar mgf emerald floors premier  sector 65   2.77
# 19          flat               afnhb jalvayu vihar  sector 30   0.85
# 25          flat                chanderlok society  sector 28   0.90
#
#     price_per_sqft    area                      areaWithType  bedRoom  \
# 1           8597.0  1105.0  Carpet area: 1103 (102.47 sq.m.)        2
# 11         14545.0  1100.0  Carpet area: 1100 (102.19 sq.m.)        2
# 13         14025.0  1975.0  Carpet area: 1975 (183.48 sq.m.)        4
# 19         12859.0   661.0    Carpet area: 661 (61.41 sq.m.)        2
# 25          7235.0  1244.0  Carpet area: 1244 (115.57 sq.m.)        4
#
#     bathroom balcony  floorNum      facing   agePossession  \
# 1          2       2       4.0         NaN    New Property
# ...

# %%
c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)
# Out:
# C:\Users\nitis\AppData\Local\Temp\ipykernel_10800\2136919732.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)
# C:\Users\nitis\AppData\Local\Temp\ipykernel_10800\2136919732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.update(c_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1014
# agePossession             0
# super_built_up_area    1686
# built_up_area             7
# carpet_area            1719
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
all_nan = df[df['built_up_area'].isnull()]

# df = df[df['built_up_area'].notnull()]

df = df.dropna(subset=['built_up_area'])

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1013
# agePossession             0
# super_built_up_area    1679
# built_up_area             0
# carpet_area            1712
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
sns.scatterplot(x=df['built_up_area'],y=df['price'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
df[df['built_up_area'] > 60000]
# Out:
#    property_type                    society     sector  price  price_per_sqft  \
# 44         house  ganpati heights apartment  sector 13   1.25         12077.0
#
#       area                  areaWithType  bedRoom  bathroom balcony  floorNum  \
# 44  1035.0  Plot area 115(7692.86 sq.m.)        1         6       2       3.0
#
#         facing agePossession  super_built_up_area  built_up_area  carpet_area  \
# 44  South-East  Old Property                  NaN       82775.17          NaN
#
#     study room  servant room  store room  pooja room  others  furnishing_type  \
# 44           0             0           0           0       1                1
#
#     luxury_score  area_room_ratio
# 44             7           1035.0

# %%
df = df[df['built_up_area']< 60000]

# %%
sns.scatterplot(x=df['built_up_area'],y=df['price'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
anamoly_df = df[(df['built_up_area'] < 2000) & (df['price'] > 2.5)][['price','area','built_up_area']]
anamoly_df.shape
# Out:
# (263, 3)

# %%
# huge difference in the area and build_up_area column values, may be because of data
# simply swap the values
anamoly_df.sample(5)
# Out:
#       price    area  built_up_area
# 3058   5.30  1935.0        1934.33
# 239    2.55  1630.0        1811.00
# 1188   2.85  1950.0        1920.00
# 2625   2.60  1080.0        1079.66
# 2860   5.50  3240.0         355.00

# %%
anamoly_df['built_up_area'] = anamoly_df['area']

# %%
df.update(anamoly_df)

# %%
sns.scatterplot(x=df['built_up_area'],y=df['price'])  # now above shown graph is changed and looking more linear characterstics value
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
df.drop(columns=['area','areaWithType','super_built_up_area','carpet_area','area_room_ratio'],inplace=True)
# Out:
# C:\Users\nitis\AppData\Local\Temp\ipykernel_10800\1475093290.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['area','areaWithType','super_built_up_area','carpet_area','area_room_ratio'],inplace=True)

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat       breez global hill view  sohna road   0.32
# 3          flat  bestech park view sanskruti   sector 92   1.60
# 4          flat               suncity avenue  sector 102   0.48
#
#    price_per_sqft  bedRoom  bathroom balcony  floorNum      facing  \
# 0          7586.0        3         2       2       2.0         NaN
# 1          8597.0        2         2       2       4.0         NaN
# 2          5470.0        2         2       1      17.0         NaN
# 3          8020.0        3         4      3+      10.0  North-West
# 4          9023.0        2         2       1       5.0  North-East
#
#     agePossession  built_up_area  study room  servant room  store room  \
# 0    New Property          850.0           0             0           0
# ...

# %%
df.isnull().sum()
# Out:
# property_type         0
# society               1
# sector                0
# price                 0
# price_per_sqft        0
# bedRoom               0
# bathroom              0
# balcony               0
# floorNum             17
# facing             1013
# agePossession         0
# built_up_area         0
# study room            0
# servant room          0
# store room            0
# pooja room            0
# others                0
# furnishing_type       0
# luxury_score          0
# dtype: int64

# %% [markdown]
# ### floorNum

# %%
df[df['floorNum'].isnull()]
# Out:
#      property_type                  society             sector  price  \
# 500          house              independent           sector 4   0.65
# 768          house              independent           sector 7   6.50
# 1296         house              independent           sector 3   1.50
# 1454         house       vipul tatvam villa          sector 48   8.50
# 1467         house  ansal sushant lok plots          sector 43   3.30
# 1951         house               jacob pura          sector 12   0.35
# 2053         house       vipul tatvam villa          sector 48   8.50
# 2162         house              independent           sector 4   4.12
# 2276         house       emaar mgf marbella          sector 66   9.00
# 2444         house     dlf new town heights          sector 86   2.47
# 2541          flat                      NaN          sector 78   0.60
# 2550         house        ansal sushant lok          sector 43  10.50
# ...

# %%
df[df['property_type'] == 'house']['floorNum'].median()
# Out:
# 2.0

# %%
df['floorNum'].fillna(2.0,inplace=True)
# Out:
# C:\Users\nitis\AppData\Local\Temp\ipykernel_10800\15612474.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['floorNum'].fillna(2.0,inplace=True)
# C:\Users\nitis\AppData\Local\Temp\ipykernel_10800\15612474.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['floorNum'].fillna(2.0,inplace=True)

# %%
df.isnull().sum()
# Out:
# property_type         0
# society               1
# sector                0
# price                 0
# price_per_sqft        0
# bedRoom               0
# bathroom              0
# balcony               0
# floorNum              0
# facing             1013
# agePossession         0
# built_up_area         0
# study room            0
# servant room          0
# store room            0
# pooja room            0
# others                0
# furnishing_type       0
# luxury_score          0
# dtype: int64

# %%
1011/df.shape[0]
# Out:
# 0.2845482690683929

# %% [markdown]
# ### facing

# %%
df['facing'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.drop(columns=['facing'],inplace=True)
# Out:
# C:\Users\nitis\AppData\Local\Temp\ipykernel_10800\3119644739.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['facing'],inplace=True)

# %%
df.sample(5)
# Out:
#      property_type                           society      sector  price  \
# 3329          flat                 hcbs sports ville  sohna road   0.30
# 680           flat                       tulip lemon   sector 69   0.62
# 397           flat  emaar mgf emerald floors premier   sector 65   2.25
# 2208          flat                       birla navya  sector 63a   3.15
# 2220          flat           indiabulls centrum park  sector 103   1.05
#
#       price_per_sqft  bedRoom  bathroom balcony  floorNum       agePossession  \
# 3329          4011.0        2         2       2       3.0           Undefined
# 680          12863.0        2         2       1       4.0      Relatively New
# 397          13636.0        3         3       3       3.0      Relatively New
# 2208         14631.0        3         3       3       4.0  Under Construction
# 2220          5859.0        2         2       3       1.0      Relatively New
#
# ...

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            1
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %%
df.drop(index=[2536],inplace=True)
# Out:
# C:\Users\nitis\AppData\Local\Temp\ipykernel_10800\2461853807.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(index=[2536],inplace=True)

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            1
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %% [markdown]
# ### agePossession

# %%
df['agePossession'].value_counts()

# need to solve meaning of the undefined section
# try to find some sort of realtion between agePossession and property_type (statistical realtion)
# then fill out the values for undefined agePossession
# Out:
# agePossession
# Relatively New        1604
# New Property           556
# Moderately Old         543
# Undefined              293
# Old Property           292
# Under Construction     264
# Name: count, dtype: int64

# %%
df[df['agePossession'] == 'Undefined']
# Out:
#      property_type                                 society      sector  price  \
# 10           house                             independent  sector 109   1.55
# 33           house                             greenopolis   sector 89   0.70
# 48            flat                        smart world gems   sector 89   1.71
# 70            flat                             rof aalayas  sector 102   0.45
# 74           house                         bhim garh kheri    sector 3   1.50
# ...            ...                                     ...         ...    ...
# 3503          flat                         raheja vedaanta  sector 108   0.70
# 3508          flat                   signature global city  sector 37d   1.10
# 3514         house                             independent   sector 21   0.45
# 3526          flat                       sidhartha ncr one   sector 95   0.57
# 3555         house  surendra homes dayaindependentd colony    sector 6   0.75
#
# ...

# %%
def mode_based_imputation(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['sector'] == row['sector']) & (df['property_type'] == row['property_type'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0]
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation,axis=1)
# Out:
# C:\Users\nitis\AppData\Local\Temp\ipykernel_10800\4034012990.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['agePossession'] = df.apply(mode_based_imputation,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1715
# New Property           596
# Moderately Old         582
# Old Property           326
# Under Construction     278
# Undefined               55
# Name: count, dtype: int64

# %%
def mode_based_imputation2(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['sector'] == row['sector'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0]
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation2,axis=1)
# Out:
# C:\Users\nitis\AppData\Local\Temp\ipykernel_10800\3682362591.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['agePossession'] = df.apply(mode_based_imputation2,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1726
# New Property           597
# Moderately Old         589
# Old Property           329
# Under Construction     278
# Undefined               33
# Name: count, dtype: int64

# %%
def mode_based_imputation3(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['property_type'] == row['property_type'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0]
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation3,axis=1)
# Out:
# C:\Users\nitis\AppData\Local\Temp\ipykernel_10800\4276506457.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['agePossession'] = df.apply(mode_based_imputation3,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1728
# Moderately Old         620
# New Property           597
# Old Property           329
# Under Construction     278
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            1
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %%
df.to_csv('../gurgaon_data/gurgaon_properties_missing_value_imputation.csv',index=False)

# %%
df.shape
# Out:
# (3552, 18)

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            1
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64
